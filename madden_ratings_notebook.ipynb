# %% [markdown]
# # What is the relationship between a players on field performance and their rating in Madden?
#
# 1) What does Madden think are the most important statistics?
#
# 2) Do madden ratings do a good job of predicting performance?
#
# *The current data only examines QBs but the scrapper can be easily modified*

# %%
#setup env
import pandas as pd
from pandas.tools.plotting import scatter_matrix
from urllib import urlopen
import scipy
import numpy as np
import pylab as pl  
from patsy import dmatrices
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
# %matplotlib inline

import json
plt_styles_url = "https://raw.githubusercontent.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/master/styles/bmh_matplotlibrc.json"
r = urlopen(plt_styles_url)
plt_styles = json.load(r)
pl.rcParams.update(plt_styles)

# %% [markdown]
# The data was scrapped from the following two sites and matched with nfl statistics

# %%
from IPython.core.display import HTML

# %%
HTML("<iframe src=http://maddenratings.weebly.com/madden-nfl-15-key-players.html width=800 height=350></iframe>")
# Out:
# <iframe src=http://maddenratings.weebly.com/madden-nfl-15-key-players.html width=800 height=350></iframe>

# %%
HTML("<iframe src=http://www.footballoutsiders.com/stats/qb2012 width=800 height=350></iframe>")
# Out:
# <iframe src=http://www.footballoutsiders.com/stats/qb2012 width=800 height=350></iframe>

# %% [markdown]
# # 1) What does Madden think are the most important statistics?
# - Are madden ratings smart?

# %%
madden_from_stats_url = 'https://raw.githubusercontent.com/bcutrell/ga_data_science/master/qb_madden_rating_from_stats.csv'
page = urlopen(madden_from_stats_url)
df = pd.read_csv(page)

# %%
# hacky data cleanup
df['QBR'][df['Year'] == df['Year'][200]] = np.nan
df['QBR'][df['Year'] == df['Year'][1]] = np.nan
pd.to_datetime(df['Year'], coerce=True)
df['Year'] =  pd.DatetimeIndex(df['Year']).year
full_df = df.dropna()

# %%
x_attrs = ['QBR', 'DVAR', 'Yards','TD', 'DVOA', 'INT']
y_attr = 'Rating'

# %% [markdown]
# The NFL database does not hold any data before 2009. There was also a lot of other missing data from all sources

# %%
df.head()
# Out:
#         Name Position  Rating  Year  DVOA  QBR  DVAR  Yards  TD  INT
# 0    T.Brady       QB      99  2008  54.1  NaN  2674    NaN NaN  NaN
# 1  P.Manning       QB      99  2008  37.1  NaN  1721    NaN NaN  NaN
# 2    B.Favre       QB      89  2008  24.5  NaN  1311    NaN NaN  NaN
# 3     T.Romo       QB      84  2008  22.5  NaN  1191    NaN NaN  NaN
# 4    D.Brees       QB      95  2008  14.2  NaN  1159    NaN NaN  NaN

# %%
full_df.head()
# Out:
#          Name Position  Rating  Year  DVOA   QBR  DVAR  Yards  TD  INT
# 63    T.Brady       QB      97  2010  40.4  65.1  2021   4398  28   13
# 64   P.Rivers       QB      89  2010  41.7  74.7  1776   4254  28    9
# 65  P.Manning       QB      99  2010  34.0  82.9  1771   4500  33   16
# 66    D.Brees       QB      96  2010  36.7  79.7  1692   4388  34   11
# 67   M.Schaub       QB      77  2010  29.3  70.3  1624   4770  29   15

# %%
df[x_attrs].hist(figsize=(10,10));

# %%
scatter_matrix(df[x_attrs], alpha=0.2, figsize=(10, 10), diagonal='kde');

# %% [markdown]
# #### Declare some graphing functions

# %%
def corr(df, method="spearman"):
  '''
    Pearson vs. Spearman
    
    Spearman: a distribution free rank statistic used to 
    determine the strength of association between two variables. It is not a measure of the
    linear relationship

    Pearson: ranks the relationship between varaibles assuming a normal distribution

    *Missing Tau, which is generally the most preferred method...
  '''
  results = []
  for x_attr in x_attrs:
    attr = {}
    if method=="spearman":
      result = scipy.stats.spearmanr(df['Rating'], df[x_attr])
    elif method=="pearson":
      result = scipy.stats.pearsonr(df[x_attr], df['Rating'])
    else:
      return "No method for " + method

    attr['attr'] = x_attr
    attr['corr'] = result[0]
    attr['pval'] = result[1]
    results.append(attr)

  return pd.DataFrame(results)

# %%
def corr_matix(df):
  corr_df = df.corr()
  pl.pcolor(corr_df)
  pl.yticks(np.arange(0.5, len(corr_df), 1), corr_df.index)
  pl.xticks(np.arange(0.5, len(corr_df), 1), corr_df.columns)
  pl.show()

# %%
def player_graph(player):
  fig, axes = pl.subplots(nrows=2, ncols=1, figsize=(12,12))
  player[x_attrs].pct_change()[:-1].plot(ax=axes[0], kind='bar'); axes[0].set_title(player['Name'][2010])
  player['Rating'].plot(ax=axes[1], linewidth=6)
  axes[0].get_xaxis().set_ticks([])

# %%
def players_graph(*players):
  x_idx = 0
  fig, axes = pl.subplots(nrows=4, ncols=2, figsize=(16,16))
  for player in players:
    player[x_attrs].pct_change()[:-1].plot(ax=axes[x_idx,0], kind='bar'); axes[x_idx,0].set_title(player['Name'][2010])
    player['Rating'].plot(ax=axes[x_idx,1], linewidth=6); axes[x_idx,1].set_title(player['Name'][2010])
    axes[x_idx,0].get_xaxis().set_ticks([])
    if not x_idx == 3:
      axes[x_idx,1].get_xaxis().set_ticks([])
    x_idx += 1

# %%
def two_by_three_scatter():
  f, axarr = pl.subplots(2, 3, sharey=True, figsize=(10,10))
  r, c = 0, 0
  for x_attr in x_attrs:
    if c == 3:
      r += 1; c = 0

    if c == 0:
      axarr[r,c].set_ylabel(y_attr)

    axarr[r, c].scatter(X[x_attr], y)

    temp_y, temp_X = dmatrices(('Rating ~ ' + x_attr), data=df, return_type='dataframe')
    model = LinearRegression()
    model = model.fit(temp_X,temp_y)
    axarr[r,c].plot(temp_X[x_attr], model.predict(temp_X), color='red', linewidth=2)
    axarr[r, c].set_title(x_attr)
    axarr[r, c].set_xticks(())
    c += 1

# %% [markdown]
# ## Correlation Coefficients

# %%
corr_matix(df);

# %%
corr(df)
# Out:
#     attr      corr          pval
# 0    QBR  0.337130  1.942831e-08
# 1   DVAR  0.547210  5.057309e-22
# 2  Yards  0.288561  1.859400e-06
# 3     TD  0.284510  2.623810e-06
# 4   DVOA  0.530459  1.460594e-20
# 5    INT  0.130129  3.457483e-02

# %%
corr(full_df)
# Out:
#     attr      corr          pval
# 0    QBR  0.557786  3.907100e-14
# 1   DVAR  0.570585  7.479427e-15
# 2  Yards  0.401677  2.023528e-07
# 3     TD  0.407080  1.336584e-07
# 4   DVOA  0.565051  1.542017e-14
# 5    INT  0.121342  1.313099e-01

# %%
corr(full_df, 'pearson') # assumes normal distribution
# Out:
#     attr      corr          pval
# 0    QBR  0.535712  5.759411e-13
# 1   DVAR  0.581823  1.649347e-15
# 2  Yards  0.386936  6.046964e-07
# 3     TD  0.460371  1.477637e-09
# 4   DVOA  0.539306  3.766183e-13
# 5    INT  0.140336  8.057576e-02

# %%
regr = y_attr + ' ~ ' + " + ".join(x_attrs)
y, X = dmatrices(regr, data=df, return_type='dataframe')

# %%
two_by_three_scatter()

# %% [markdown]
# # Who the hell is that lower dot?

# %%
from IPython.core.display import Image

# %% [markdown]
# ## Matthew Stafford?

# %%
Image(url='http://www.sportsgrindent.com/blog/wp-content/uploads/2010/06/matthew-stafford-21.jpg', width=500 , height=500)
# Out:
# <img src="http://www.sportsgrindent.com/blog/wp-content/uploads/2010/06/matthew-stafford-21.jpg" width="500" height="500"/>

# %%
mstafford = df[df['Name'] == 'M.Stafford'].set_index('Year')
player_graph(mstafford)

# %% [markdown]
# # Nooooo.... Actually it's

# %%
df[(df["Rating"] > 50) & (df["Rating"] < 60)]
# Out:
#        Name Position  Rating  Year  DVOA   QBR  DVAR  Yards  TD  INT
# 80  M.Moore       QB      55  2010    17  59.2   262   1053   8    2

# %% [markdown]
# # Now, let's look at some real players

# %%
tbrady = df[df['Name'] == 'T.Brady'].set_index('Year')
pmanning = df[df['Name'] == 'P.Manning'].set_index('Year')
broberger = df[df['Name'] == 'B.Roethlisberger'].set_index('Year')
dbrees = df[df['Name'] == 'D.Brees'].set_index('Year')

# %%
players_graph(tbrady, pmanning, broberger, dbrees)

# %%
player_graph(tbrady)

# %%
player_graph(pmanning)

# %% [markdown]
# # 2) Do madden ratings do a good job of predicting performance?

# %%
stats_from_madden_url = 'https://raw.githubusercontent.com/bcutrell/ga_data_science/master/qb_stats_from_madden_rating.csv'
page = urlopen(stats_from_madden_url)
df = pd.read_csv(page)

# %%
# hacky data cleanup
df['QBR'][df['Year'] == df['Year'][200]] = np.nan
df['QBR'][df['Year'] == df['Year'][1]] = np.nan
pd.to_datetime(df['Year'], coerce=True)
df['Year'] =  pd.DatetimeIndex(df['Year']).year
full_df = df.dropna()

# %%
corr_matix(df)

# %%
corr(df)
# Out:
#     attr      corr          pval
# 0    QBR  0.203662  1.231454e-03
# 1   DVAR  0.422886  3.188230e-12
# 2  Yards  0.192275  2.309335e-03
# 3     TD  0.183686  3.629098e-03
# 4   DVOA  0.425649  2.225873e-12
# 5    INT  0.084342  1.846530e-01

# %%
corr(full_df)
# Out:
#     attr      corr          pval
# 0    QBR  0.512516  2.544732e-09
# 1   DVAR  0.551274  8.198732e-11
# 2  Yards  0.587296  2.211722e-12
# 3     TD  0.594337  1.035294e-12
# 4   DVOA  0.522509  1.093443e-09
# 5    INT  0.258825  4.479683e-03

# %%
corr(full_df, 'pearson')
# Out:
#     attr      corr          pval
# 0    QBR  0.509370  3.301339e-09
# 1   DVAR  0.591355  1.431061e-12
# 2  Yards  0.577383  6.246947e-12
# 3     TD  0.602630  4.133807e-13
# 4   DVOA  0.521970  1.145279e-09
# 5    INT  0.255324  5.071342e-03

# %%
tbrady = df[df['Name'] == 'T.Brady'].set_index('Year')
pmanning = df[df['Name'] == 'P.Manning'].set_index('Year')
broberger = df[df['Name'] == 'B.Roethlisberger'].set_index('Year')
dbrees = df[df['Name'] == 'D.Brees'].set_index('Year')

# %%
players_graph(tbrady, pmanning, broberger, dbrees)

# %%
player_graph(tbrady)

# %%
player_graph(pmanning)

# %%
Image(url='http://bigcommentary.com/wp-content/uploads/2014/01/brady-manning-260x148.jpg', width=500 , height=500)
# Out:
# <img src="http://bigcommentary.com/wp-content/uploads/2014/01/brady-manning-260x148.jpg" width="500" height="500"/>
